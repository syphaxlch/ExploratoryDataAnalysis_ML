# %%
import pandas as pd
import os
import yaml

# %%
# List files in the data folder
data_files = os.listdir('data')
print(data_files)
# Out:
# ['data.json', 'dictionary.yml', 'schema.ddl', 'schema.jsch']

# %%
import pandas as pd

# Charger le fichier JSON Lines dans un DataFrame
df = pd.read_json('data/data.json', encoding='utf-8', lines=True)
# Afficher les premières lignes du DataFrame
df.head()
# Out:
#    bgpDestinationAsNumber  bgpSourceAsNumber  biFlowEndMilliseconds  \
# 0                       0               3356          1552989600071
# 1                       0               3356          1552989600071
# 2                       0               3356          1552989600079
# 3                       0               3356          1552989600081
# 4                       0               3356          1552989600083
#
#    biFlowStartMilliseconds destinationIPv4Address  destinationTransportPort  \
# 0            1552989600068             9.66.66.12                     110.0
# 1            1552989600067             9.66.66.12                     587.0
# 2            1552989600074             9.66.66.12                     143.0
# 3            1552989600079             9.66.66.13                      53.0
# 4            1552989600079             9.66.66.12                      25.0
#
#   exercise_dst_ipv4_segment                           extendedFlow  \
# ...

# %%
df
# Out:
#         bgpDestinationAsNumber  bgpSourceAsNumber  biFlowEndMilliseconds  \
# 0                            0               3356          1552989600071
# 1                            0               3356          1552989600071
# 2                            0               3356          1552989600079
# 3                            0               3356          1552989600081
# 4                            0               3356          1552989600083
# ...                        ...                ...                    ...
# 469108                       0               3356          1553091920073
# 469109                       0               3356          1553091920073
# 469110                    3356                  0          1553091920120
# 469111                    3356                  0          1553091920256
# 469112                    3356               3356          1553091920370
#
#         biFlowStartMilliseconds destinationIPv4Address  \
# ...

# %% [markdown]
# # Chargement de dictionary.yml

# %%
with open('data/dictionary.yml', 'r') as file:
    data_yaml = yaml.safe_load(file)

# %%
df_dict = pd.DataFrame(data_yaml['data-schema'])
df_dict
# Out:
#                             name                       type  \
# 0                  applicationId   string (nullable = true)
# 1                applicationName   string (nullable = true)
# 2         bgpDestinationAsNumber     long (nullable = true)
# 3              bgpSourceAsNumber     long (nullable = true)
# 4          biFlowEndMilliseconds     long (nullable = true)
# 5        biFlowStartMilliseconds     long (nullable = true)
# 6         destinationIPv4Address   string (nullable = true)
# 7         destinationIPv6Address   string (nullable = true)
# 8       destinationTransportPort  integer (nullable = true)
# 9      exercise_dst_ipv4_segment   string (nullable = true)
# 10                  extendedFlow   struct (nullable = true)
# 11           flowEndMilliseconds     long (nullable = true)
# 12       flowEndMilliseconds_Rev     long (nullable = true)
# 13         flowStartMilliseconds     long (nullable = true)
# 14     flowStartMilliseconds_Rev     long (nullable = true)
# ...

# %%
# Filtrer les éléments dont le type est un struct
df_struct = df_dict[df_dict['type'].str.contains('struct', na=False)]

# Afficher les éléments struct
print(df_struct)
# Out:
#             name                      type                       description  \
# 10  extendedFlow  struct (nullable = true)  RAW application-aware flow data.
#
#                                                fields
# 10  [{'name': 'dhcp', 'type': 'string (nullable = ...

# %%
# Accéder au struct extendedFlow
df_extended_flow = df_dict[df_dict['name'] == 'extendedFlow']

# Afficher les sous-champs de extendedFlow (s'ils sont définis)
df_extended_flow['fields'].iloc[0]  # Si les sous-champs sont dans la première ligne
# Out:
# [{'name': 'dhcp',
#   'type': 'string (nullable = true)',
#   'description': 'RAW data - parsed DHCP communication.'},
#  {'name': 'dns',
#   'type': 'string (nullable = true)',
#   'description': 'RAW data - parsed DNS communication.'},
#  {'name': 'http',
#   'type': 'string (nullable = true)',
#   'description': 'RAW data - parsed HTTP communication.'},
#  {'name': 'mail',
#   'type': 'string (nullable = true)',
#   'description': 'RAW data - parsed e-mail communication.'},
#  {'name': 'pgsql',
#   'type': 'string (nullable = true)',
#   'description': 'RAW data - parsed PostgreSQL communication.'},
#  {'name': 'smtp',
#   'type': 'string (nullable = true)',
#   'description': 'RAW data - parsed SMTP communication.'},
#  {'name': 'tcp',
#   'type': 'string (nullable = true)',
#   'description': 'RAW data - various TCP metrics.'},
#  {'name': 'tls',
#   'type': 'string (nullable = true)',
#   'description': 'RAW data - parsed TLS communication.'}]
